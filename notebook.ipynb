# %% [markdown]
# # Temat pracy
# Wybrałem temat: "Przemiany energetyczne w Europie" - analiza zmian w udziale odnawialnych źródeł energii w róznych krajach Europy
#
# ## Opis tematu
# Moim celem w podanym temacie jest sprawdzenie udziału OZE w generowaniu energii elektrycznej w całej Unii Europejskiej. Chcę sprawdzić co dzieje się z tym udziałem z roku na rok, które
# kraje nie inwestują w OZE oraz które państwo ma największe udziały w OZE w całej Unii Europejskiej. Dodatkowo chcę przeprowadzić analizy jak udział OZE wpływa na generowanie
#
#
#
#
#
# Tak, możesz wykorzystać raporty Eurostatu dotyczące „energy efficiency” (efektywności energetycznej) do analizy, czy OZE (odnawialne źródła energii) wpływają na wydajność energetyczną, ale wymaga to odpowiedniego podejścia i interpretacji danych.
#
# ## Jak to wygląda w praktyce?
#
# - **Efektywność energetyczna** mierzy, ile energii potrzeba do uzyskania określonego efektu (np. wyprodukowania jednostki PKB, ogrzania budynku, transportu tony towaru). Im mniej energii zużywasz na ten sam efekt, tym wyższa efektywność.
# - **OZE** same w sobie nie zawsze bezpośrednio zwiększają efektywność energetyczną, bo efektywność dotyczy raczej tego, jak dobrze wykorzystywana jest energia, niezależnie od jej źródła. Jednak przechodzenie na OZE często wiąże się z modernizacją infrastruktury, lepszymi technologiami i bardziej efektywnym zużyciem energii, co może pośrednio poprawiać efektywność energetyczną[1][2][3].
#
# ## Co pokazują dane Eurostatu?
#
# - Statystyki Eurostatu pozwalają śledzić zarówno udział OZE w zużyciu energii, jak i wskaźniki efektywności energetycznej (np. energochłonność gospodarki, zużycie energii końcowej na jednostkę PKB).
# - Możesz porównywać kraje lub lata pod kątem tego, czy wzrost udziału OZE idzie w parze ze spadkiem energochłonności lub zużycia energii na mieszkańca[2][3].
# - Badania naukowe (np. [1]) pokazują, że wzrost udziału OZE w miksie energetycznym UE koreluje z poprawą wskaźników środowiskowych (np. spadkiem emisji CO₂), a często także z poprawą efektywności energetycznej, choć wpływ ten jest pośredni i zależy od wielu czynników (technologie, struktura gospodarki, polityka energetyczna).
#
# ## Na co zwrócić uwagę?
#
# - Wskaźniki efektywności energetycznej i udziału OZE to różne miary, ale ich zestawienie pozwala analizować, czy transformacja energetyczna idzie w parze z poprawą wydajności zużycia energii.
# - Przykładowo, jeśli kraj zwiększa udział OZE i jednocześnie spada jego zużycie energii na PKB, można mówić o pozytywnym wpływie transformacji na efektywność energetyczną.
# - Warto korzystać z danych na poziomie krajowym i sektorowym (np. przemysł, transport, budownictwo), by zobaczyć, gdzie efekty są najsilniejsze.
#
# ## Podsumowanie
#
# **Tak, raporty Eurostatu o efektywności energetycznej można wykorzystać do analizy wpływu OZE na wydajność energetyczną, ale wymaga to porównania wskaźników udziału OZE oraz wskaźników efektywności energetycznej w czasie lub pomiędzy krajami.** Efekt ten jest pośredni i zależy od wielu czynników, ale takie analizy są szeroko stosowane w badaniach nad polityką energetyczną i transformacją energetyczną UE[1][2][3][4][5].
#
# Sources
# [1] Measuring the Renewable Energy Efficiency at the European Union ... https://www.mdpi.com/2227-9717/7/12/923
# [2] Share of energy consumption from renewable sources in Europe https://www.eea.europa.eu/en/analysis/indicators/share-of-energy-consumption-from
# [3] Calculation methodologies for the share of renewables in energy ... https://ec.europa.eu/eurostat/statistics-explained/index.php/Calculation_methodologies_for_the_share_of_renewables_in_energy_consumption
# [4] Zainteresowania interests.energy_policy
# [5] Zainteresowania interests.energy
# [6] Shedding light on energy in Europe – 2024 edition - EC Europa https://ec.europa.eu/eurostat/web/interactive-publications/energy-2024
# [7] Electricity from renewable sources reaches 47% in 2024 - EC Europa https://ec.europa.eu/eurostat/web/products-eurostat-news/w/ddn-20250319-1
# [8] Energy efficiency statistics - Statistics Explained - Eurostat - EC Europa https://ec.europa.eu/eurostat/statistics-explained/index.php?title=Energy_efficiency_statistics
# [9] Shedding light on energy in Europe – 2025 edition - EC Europa https://ec.europa.eu/eurostat/web/interactive-publications/energy-2025
# [10] RENEWABLE ENERGY SOURCES IN THE EU – CURRENT STATE ... https://zeszytynaukowe-sgsp.pl/seo/article/01.3001.0053.8566/en
# [11] The dynamics of energy transition in European countries in years ... https://ekonomiaisrodowisko.pl/journal/article/view/634
# [12] Energy efficiency | European Environment Agency's home page https://www.eea.europa.eu/en/topics/in-depth/energy-efficiency
#
#
#
# Różnica między **final energy consumption** (zużyciem energii końcowej) a **primary energy consumption** (zużyciem energii pierwotnej) w raporcie Eurostatu „Energy efficiency” polega na tym, na jakim etapie „drogi” energii przez gospodarkę są one mierzone i co obejmują.
#
# ---
#
# ## Primary energy consumption (PEC) – zużycie energii pierwotnej
#
# - **Definicja:** To całkowite zapotrzebowanie na energię w kraju, obejmujące:
#   - energię zużytą przez końcowych odbiorców,
#   - straty podczas produkcji i przesyłu,
#   - zużycie energii przez sam sektor energetyczny (np. praca elektrowni),
#   - energię zużytą na transformację (np. spalanie węgla do produkcji prądu),
#   - z wyłączeniem energii użytej do celów nieenergetycznych (np. ropa do produkcji plastiku)[2][6].
# - **Co mierzy:** Pokazuje, ile energii pierwotnie „weszło” do systemu energetycznego kraju — zanim została przetworzona, przesłana i zużyta przez odbiorców końcowych.
# - **Przykład:** Jeśli gospodarstwo domowe zużyje 1 kWh prądu, a wyprodukowanie tej 1 kWh w elektrowni węglowej wymagało spalenia węgla o wartości 2,5 kWh energii pierwotnej (ze względu na sprawność i straty), to do PEC zalicza się właśnie te 2,5 kWh.
#
# ---
#
# ## Final energy consumption (FEC) – zużycie energii końcowej
#
# - **Definicja:** To ilość energii, która dociera do końcowych odbiorców (gospodarstw domowych, przemysłu, transportu, rolnictwa itd.) i jest przez nich zużywana[1][4][6].
# - **Co mierzy:** Pokazuje realne zużycie energii „na miejscu” – to, co faktycznie trafia do użytkowników po wszystkich transformacjach i przesyle.
# - **Przykład:** Jeśli gospodarstwo domowe zużyje 1 kWh prądu, to właśnie ta 1 kWh wlicza się do FEC.
#
# ---
#
# ## Różnice i zależności
#
# - **PEC jest zawsze większe od FEC**, ponieważ obejmuje straty, zużycie energii przez sektor energetyczny i procesy transformacji, zanim energia dotrze do końcowego odbiorcy[1][2][6].
# - **FEC** to energia „u klienta”, **PEC** to energia „na wejściu” do całej gospodarki.
#
# ---
#
# ### Podsumowanie w tabeli
#
# | Wskaźnik                    | Co obejmuje?                                                                                   | Przykład                          |
# |-----------------------------|-----------------------------------------------------------------------------------------------|-----------------------------------|
# | Primary energy consumption   | Całkowite zapotrzebowanie na energię, łącznie z transformacją, stratami, sektorem energetycznym | 2,5 kWh węgla potrzebne na 1 kWh prądu |
# | Final energy consumption     | Energia zużyta przez odbiorców końcowych (gospodarstwa, przemysł, transport)                  | 1 kWh prądu zużyte w domu         |
#
# ---
#
# **W skrócie:**
# - **Final energy consumption** – ile energii faktycznie zużywają odbiorcy końcowi.
# - **Primary energy consumption** – ile energii pierwotnej musiało być dostarczone do systemu, aby pokryć całe krajowe zapotrzebowanie, łącznie ze stratami i transformacją[1][2][4][6].
#
# Sources
# [1] Primary and final energy consumption in the European Union https://www.eea.europa.eu/en/analysis/indicators/primary-and-final-energy-consumption
# [2] Glossary:Primary energy consumption - Statistics Explained - Eurostat https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Primary_energy_consumption
# [3] Energy statistics - an overview - EC Europa - European Union https://ec.europa.eu/eurostat/statistics-explained/index.php/Energy_statistics_-_an_overview
# [4] Glossary:Final energy consumption - Statistics Explained - Eurostat https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Final_energy_consumption
# [5] [PDF] Primary and final energy consumption in ODYSSEE March 2020 https://www.odyssee-mure.eu/publications/other/definitions-primary-final-energy-consumption.pdf
# [6] EU primary energy consumption decreased 4% in 2022 - EC Europa https://ec.europa.eu/eurostat/web/products-eurostat-news/w/ddn-20231221-2
# [7] Final energy consumption in industry - detailed statistics - EC Europa https://ec.europa.eu/eurostat/statistics-explained/index.php/Final_energy_consumption_in_industry_-_detailed_statistics
# [8] [PDF] the renewable energy sources targets https://epj.min-pan.krakow.pl/pdf-109339-40518?filename=Consequences+of+the.pdf
# [9] Jenny scordamaglia miami tv https://maxxilots-affairesafaire.fr/aftenbladet/
# [10] Primary and final energy consumption in Europe - 8th EAP https://www.eea.europa.eu/et/ims/primary-and-final-energy-consumption

# %% [markdown]
# # Wyjaśnienie danych
#
# ## Wyjaśnienie nazw plików z zakładki "Energy"
# - **"nrg_ind_ren": "Share of energy from renewable sources",**
# - **nrg_inf_epc - Electricity production capacities by main fuel groups and operator (nrg_inf_epc),**
# - "nrg_ind_urtd": "Use of renewables for transport - details",
# - "nrg_ind_ured": "Use of renewables for electricity - details",
# - "nrg_ind_urhcd": "Use of renewables for heating and cooling",
# - "nrg_ind_cotd": "Calculation of overall target - details",
# - "nrg_ind_hptctc": "Heat pumps - technical characteristics by technology and climate",
# - "nrg_ind_ahbtc": "Heat pumps - ambient heat caputer by technology and climate",
# - "nrg_ind_stjpjss": "Statistical transfers, joint projects and joint support schemes",
# - "nrg_ind_rfce": "Contribution of renewable fuels to gross final consumption of energy",
# - "nrg_ind_rfcer": "Share of renewable fuels in gross final consumption of energy from renewables",
# - "nrg_ind_rftce": "Share of renewable fuels in total gross final consumption of energy",
# - **"nrg_ind_rcaebt": "Renewable cooling - ambient energy by technology",**
# - "nrg_ind_rctcbt": "Renewable cooling - technical characteristics by technology",
# - "nrg_ind_ibmg": "Imports of biomethane through the grid",
# - "nrg_ind_ebmg": "Exports of biomethane through grid",
# - "estat_nrg_inf_epc": "Electricity production capacities by main fuel groups and operator",
# - **"estat_nrg_ind_eff_filtered_en.csv": "Energy Efficiency"**
#
# ## Wyjaśnienie kolumny "Type of fuel" / "siec"
# - CF – Combustible fuels (paliwa palne, np. węgiel, gaz, ropa)
# - N9000 – Nuclear fuels and other fuels n.e.c. (energia jądrowa i inne, niesklasyfikowane)
# - RA100 – Hydro (energia wodna)
# - RA110 – Pure hydro power (czysta energia wodna)
# - RA120 – Mixed hydro power (mieszana energia wodna)
# - RA130 – Pumped hydro power (energia z elektrowni szczytowo-pompowych)
# - RA200 – Geothermal (energia geotermalna)
# - RA300 – Wind (energia wiatrowa)
# - RA310 – Wind on shore (wiatr na lądzie)
# - RA320 – Wind off shore (wiatr na morzu)
# - RA410 – Solar thermal (energia słoneczna – termiczna)
# - RA420 – Solar photovoltaic (energia słoneczna – fotowoltaika)
# - RA420AC – Solar photovoltaic – alternating current (PV prądu przemiennego)
# - RA420DC – Solar photovoltaic – direct current (PV prądu stałego)
# - RA500 – Other renewable energies (inne odnawialne źródła energii)
# - TOTAL – Total (suma całkowita)
# - X9900 – Other fuels n.e.c. (inne paliwa, niesklasyfikowane gdzie indziej)
#
#
# ## Wyjaśnienie kolumny "Type of measure" / plant_tec
# - **CAP_NET_ELC – oznacza zainstalowaną moc netto (capacity net) w elektrowniach elektrycznych (electricity). To podstawowa kategoria dotycząca mocy dostępnej w systemie elektroenergetycznym.**
# - CAP_NET_ELC_C – najprawdopodobniej odnosi się do zainstalowanej mocy netto w elektrowniach cieplnych (C – conventional/thermal), czyli tradycyjnych źródłach energii elektrycznej.
# - CAP_NET_ELC_DCM – odnosi się do zainstalowanej mocy netto w elektrowniach zasilanych silnikami spalinowymi (DCM – diesel/compression motors), czyli jednostkach napędzanych silnikami diesla lub innymi silnikami tłokowymi.
#
# ## Jakich danych będę uzywać?
# Będę uzywać:
# - nrg_ind_ren - Share of energy from renewable sources (nrg_ind_ren)
# - nrg_inf_epc - Electricity production capacities by main fuel groups and operator (nrg_inf_epc)
# - nrg_ind_rcaebt - Renewable cooling - ambient energy by technology (nrg_ind_rcaebt)
# - estat_nrg_ind_eff_filtered_en - estat_nrg_ind_eff_filtered_en.csv - Energy Efficiency
#
# ## Państwa, które były brane pod uwagę w pomiarach?
# - AL — Albania
# - AT — Austria
# - BA — Bośnia i Hercegowina (Bosnia and Herzegovina)
# - BE — Belgia (Belgium)
# - BG — Bułgaria (Bulgaria)
# - CY — Cypr (Cyprus)
# - CZ — Czechy (Czechia)
# - DE — Niemcy (Germany)
# - DK — Dania (Denmark)
# - EE — Estonia
# - EL — Grecja (Greece; kod EL stosowany przez Eurostat zamiast GR)
# - ES — Hiszpania (Spain)
# - FI — Finlandia
# - FR — Francja (France)
# - GE — Gruzja (Georgia)
# - HR — Chorwacja (Croatia)
# - HU — Węgry (Hungary)
# - IE — Irlandia (Ireland)
# - IT — Włochy (Italy)
# - LI — Liechtenstein
# - LT — Litwa (Lithuania)
# - LU — Luksemburg (Luxembourg)
# - LV — Łotwa (Latvia)
# - MD — Mołdawia (Moldova)
# - ME — Czarnogóra (Montenegro)
# - MK — Macedonia Północna (North Macedonia)
# - MT — Malta
# - NL — Niderlandy (Netherlands)
# - NO — Norwegia (Norway)
# - PL — Polska (Poland)
# - PT — Portugalia (Portugal)
# - RO — Rumunia (Romania)
# - RS — Serbia
# - SE — Szwecja (Sweden)
# - SI — Słowenia (Slovenia)
# - SK — Słowacja (Slovakia)
# - TR — Turcja (Turkey)
# - XK — Kosowo (Kosovo)
# Dodatkowe kody:
# - EA20 — Strefa euro (20 krajów)
# - EU27_2020 — Unia Europejska (27 krajów, stan na 2020 r.)
#
# ## Wyjaśnienie kolumny "operator"
# - PRR_AUTO — oznacza elektrownie należące do sektora autoproducentów (ang. “autoproducers”), czyli zakłady lub przedsiębiorstwa, które wytwarzają energię elektryczną głównie na własne potrzeby, a nie na sprzedaż na rynku.
# - **PRR_MAIN — oznacza elektrownie główne (ang. “main activity producers”), czyli operatorów, których podstawową działalnością jest produkcja energii elektrycznej na rynek, a nie na własny użytek.**

# %%
import os
import pandas

import matplotlib.pyplot as plt


def extend_visibility_of_data(max_rows, max_columns):
    pandas.set_option('display.max_rows', max_rows)
    pandas.set_option('display.max_columns', max_columns)

def convert_to_numeric_and_fillna(given_df, from_row, from_column, fillna_value):
    # given_df = given_df.iloc[from_row:, from_column:].apply(pandas.to_numeric, errors='coerce').fillna(fillna_value)
    given_df = given_df.iloc[from_row:, from_column:].apply(pandas.to_numeric, errors='coerce')
    return given_df

def add_labels(xs, ys, tick, line):
    line.set_marker('o')
    line.set_color('blue')
    line.set_markevery(tick)
    for i, (x,y) in enumerate(zip(xs,ys)):
        if i % tick == 0:
            label = "{:.2f}".format(y)

            plt.annotate(label, # this is the text
                        (x,y), # these are the coordinates to position the label
                        textcoords="offset points", # how to position the text
                        xytext=(0,10), # distance from text to points (x,y)
                        ha='center',
                        fontsize = 8,
                        bbox=dict(facecolor='blue', alpha=0.2)) # horizontal alignment can be left, right

def create_plot(xpoints, ypoints, ticks, title, label_name="Series1", ax=None, color='blue', disp_in_jupyter=True):
    if ax is None:
        fig, ax = plt.subplots(figsize=(12,10))

    line, = ax.plot(xpoints, ypoints, label=label_name, color=color)
    # ax.set_xticks(ticks)
    ax.set_xticks(xpoints[::ticks])
    ax.legend()
    ax.set_title(title, wrap=True)
    add_labels(xpoints, ypoints, ticks, line)
    if not disp_in_jupyter:
        plt.close()

    return line

def create_bar(xpoints, ypoints, title="Title", x_label_name="SeriesX", y_label_name="SeriesY", color="blue", disp_in_jupyter=True):
    plt.figure()
    bar = plt.bar(xpoints, ypoints, color=color)
    plt.title(title)
    plt.xlabel(x_label_name)
    plt.ylabel(y_label_name)    

    if not disp_in_jupyter:
        plt.close()

    return bar

def create_labels_bar(x, y, label_color='blue', alpha=1.0, boxstyle='square', font_color="black"):
    for i in range (len(x)):
        plt.text(i, y[i], y[i], ha="center", color=font_color, bbox=dict(facecolor=label_color, alpha=alpha, boxstyle=boxstyle))

def iter_through_cols(given_df, func):
    single_values_to_return = {}
    for series_name in given_df.columns:
        single_values_to_return[series_name] = func(given_df[series_name])
    
    return single_values_to_return

def convert_dict_to_df(given_dict, title_keys_col, title_val_col):
    converted_df = pandas.DataFrame({title_keys_col: given_dict.keys(), title_val_col: given_dict.values()})
    return converted_df

# %%
listOfFiles = os.listdir()

#TODO trzeba pozmieniać nazwy plików tak by one były zrozumiałe

#rename the files to readable names
readableNames = {
    "nrg_ind_ren": "Share of energy from renewable sources",
    "nrg_ind_urtd": "Use of renewables for transport - details",
    "nrg_ind_ured": "Use of renewables for electricity - details",
    "nrg_ind_urhcd": "Use of renewables for heating and cooling",
    "nrg_ind_cotd": "Calculation of overall target - details",
    "nrg_ind_hptctc": "Heat pumps - technical characteristics by technology and climate",
    "nrg_ind_ahbtc": "Heat pumps - ambient heat caputer by technology and climate",
    "nrg_ind_stjpjss": "Statistical transfers, joint projects and joint support schemes",
    "nrg_ind_rfce": "Contribution of renewable fuels to gross final consumption of energy",
    "nrg_ind_rfcer": "Share of renewable fuels in gross final consumption of energy from renewables",
    "nrg_ind_rftce": "Share of renewable fuels in total gross final consumption of energy",
    "nrg_ind_rcaebt": "Renewable cooling - ambient energy by technology",
    "nrg_ind_rctcbt": "Renewable cooling - technical characteristics by technology",
    "nrg_ind_ibmg": "Imports of biomethane through the grid",
    "nrg_ind_ebmg": "Exports of biomethane through grid",
    "estat_nrg_inf_epc": "Electricity production capacities by main fuel groups and operator",
    "estat_nrg_ind_eff_filtered_en.csv": "Energy Efficiency"
}




df = pandas.read_csv("estat_nrg_inf_epc.tsv", sep='\t')

# %%
#Wyciągnij kolumny z samymi danymi
dfOnlyValues = df.iloc[:, 1:]
dfOnlyValues

#Rozdziel kolumnę z nagłówkami (które są po przecinku) a następnie stwórz z nimi kolumny oddzielne
dfHeadings = df.iloc[:, 0].str.split(",", expand=True)

#Połącz wszystko powyżej w całość. Konkatenacja kolumn
df = pandas.concat([dfHeadings, dfOnlyValues], ignore_index=False, sort=False, axis=1)

#freq,siec,plant_tec,operator,unit,geo\TIME_PERIOD

#Utworzenie tablicy ze zrozumiałymi nazwami kolumn
columnNames = ["Annual", "Type of fuel", "Type of measure", "Operator", "Unit", "Country"]

#Zmiana nazw kolumn tak jak jest w zmiennej columnNames
for i in range(0,6):
    df.rename(columns={df.columns[i]: columnNames[i]}, inplace=True)


###################### Tu miejsce na kod, który sprawdza jak to wygląda dla poszczegolnych krajow.
#  Trzeba obliczyć średni wzrost każdego z rodzajów elektrowni w podziale na rok
# W których latach były spadki i czy w ogóle były
# od których lat państwa zaczęły inwestować w jakieś OZE (ogólnie w które elektrownie)

df_sorted = df.sort_values(by="Country")

df_sorted

df_sorted_filtered_useful = df_sorted[(df_sorted["Type of measure"] == "CAP_NET_ELC") & (df_sorted["Operator"] == "PRR_MAIN") & (df_sorted["Type of fuel"] != "TOTAL") & (df_sorted["Country"] != "EA20") & (df_sorted["Country"] != "EU27_2020")]
df_sorted_filtered_useful = convert_to_numeric_and_fillna(df_sorted_filtered_useful, 0, 6, 0)


main_df = df_sorted[(df_sorted["Type of measure"] == "CAP_NET_ELC") & (df_sorted["Operator"] == "PRR_MAIN") & (df_sorted["Type of fuel"] != "TOTAL") & (df_sorted["Country"] != "EA20") & (df_sorted["Country"] != "EU27_2020")]
main_df.iloc[:, 6:] = convert_to_numeric_and_fillna(main_df, 0, 6, 0)



#CEL: WYSWIETL I WYMIEN KRAJE I JAKICH ELEKTROWNI UZYWAJA
#POMYSŁ NA PCA: Porównać czy wzrost udziału OZE równa się wzrostowi wydajności energetycznej. Jeśli się równa to w głownej mierze pewnie chodzi o to, ze są przebudowy sieci energetycznych co
#wpływają na wydajność całej sieci

# %%
typeOfPowerplants = {
    "CF" : "Combustible fuels (paliwa palne, np. węgiel, gaz, ropa)",
    "N9000" : "Nuclear fuels and other fuels n.e.c. (energia jądrowa i inne, niesklasyfikowane)", #ECO
    "RA100" : "Hydro (energia wodna)", #ECO
    "RA110" : "Pure hydro power (czysta energia wodna)", #ECO
    "RA120" : "Mixed hydro power (mieszana energia wodna)", #ECO
    "RA130" : "Pumped hydro power (energia z elektrowni szczytowo-pompowych)", #ECO
    "RA200" : "Geothermal (energia geotermalna)", #ECO
    "RA300" : "Wind (energia wiatrowa)", #ECO
    "RA310" : "Wind on shore (wiatr na lądzie)", #ECO
    "RA320" : "Wind off shore (wiatr na morzu)", #ECO
    "RA410" : "Solar thermal (energia słoneczna - termiczna)", #ECO
    "RA420" : "Solar photovoltaic (energia słoneczna - fotowoltaika)", #ECO
    "RA420AC" : "Solar photovoltaic - alternating current (PV prądu przemiennego)", #ECO
    "RA420DC" : "Solar photovoltaic - direct current (PV prądu stałego)", #ECO
    "RA500" : "Other renewable energies (inne odnawialne źródła energii)", #ECO
    "TOTAL" : "Total (suma całkowita)",
    "X9900" : "Other fuels n.e.c. (inne paliwa, niesklasyfikowane gdzie indziej)"
}



#Nie bierz pod uwagę Annual
total_without_annual_column = df[df.columns[1:]]

#Zmierz ogólnie jak rośnie w TOTALU produkcja prądu BEZ EA20 ORAZ BEZ EU27_2020
total_without_annual_column = total_without_annual_column[(total_without_annual_column["Operator"] == "PRR_MAIN") & (total_without_annual_column["Type of fuel"] == "TOTAL")
                                                           & (total_without_annual_column["Country"] != "EA20")
                                                           & (total_without_annual_column["Country"] != "EU27_2020")
                                                           ]

#TODO Zmierz procentowy wzrost produkcji energii 

#Wyciągnij jedynie kolumny liczbowe
columns_to_calculate_average = total_without_annual_column.iloc[:, 5:]
#Przekonwertuj dane na wartosci numeryczne i uzupelnij NaN zerami
columns_to_calculate_average = columns_to_calculate_average.apply(pandas.to_numeric, errors='coerce').fillna(0)
#Oblicz srednia dla kazdego roku dla WSZYSTKICH KRAJOW

means = iter_through_cols(columns_to_calculate_average, pandas.Series.mean)
means

df_average = convert_dict_to_df(means, "Years", "Means")

# %% [markdown]
# ## Średnia produkcja prądu w całej Unii Europejskiej wliczając w to kraje kandydujące na członka EU.
# ### Co zawierają dane?
# Dane biorą pod uwagę wszystkie metody generowania prądu (w tym sposoby konwencjonalne jak paliwa kopalne)
#
# ### Analizy
# Lista krajów uwzględnionych w analizach jest wpisana zapisana na początku.
#
# Patrząc na wykres poniżej można zauważyć, że średnia produkcja prądu w całej

# %%
#WYKRES WZROSTU ŚREDNIEJ WARTOŚCI PRODUKCJI ENERGII ELEKTYCZNEJ W EU
#PRR_MAIN — oznacza elektrownie główne (ang. “main activity producers”), czyli operatorów,
# których podstawową działalnością jest produkcja energii elektrycznej na rynek, a nie na własny użytek.

#CAP_NET_ELC – oznacza zainstalowaną moc netto (capacity net) w elektrowniach elektrycznych (electricity).
# To podstawowa kategoria dotycząca mocy dostępnej w systemie elektroenergetycznym.

xpoints = df_average["Years"]
ypoints = df_average["Means"]

#MOC JAKĄ MOŻE WYTWORZYĆ ELEKTRONIA PO ODJĘCIU SWOICH POTRZEB
line = create_plot(xpoints, ypoints, 3, "Średnia zainstalowana moc netto w elektrowniach elektrycznych przez wszystkie kraje (+kandydaci do UE) w UE 1990-2024 (MW)", disp_in_jupyter=True)

# %%
#WYGENERUJ TAKI SAM WYKRES JAK WYŻEJ TYLKO DLA KAŻDEGO KRAJU Z OSOBNA
#total_without_annual_column[total_without_annual_column["Country"] == "EA20"]
list_of_all_countries = total_without_annual_column.iloc[0:, 4].unique()
# list_of_all_countries

################################################## KOD JEST PRAWIDŁOWY I WYŚWIETLA MOCE NETTO PER KRAJ
for country in list_of_all_countries:
    if country == "EA20" or country == "EU27_2020":
        continue
    df_one_country = df_sorted[(df_sorted["Country"] == country)
                               & (df_sorted["Operator"] == "PRR_MAIN")
                                 & (df_sorted["Type of measure"] == "CAP_NET_ELC")
                                 & (df_sorted["Type of fuel"] != "TOTAL")]

    for series_name in df_one_country.columns[6:]:
        df_one_country.loc[:, series_name] = pandas.to_numeric(df_one_country[series_name], errors='coerce').fillna(0)

    means_per_country = iter_through_cols(df_one_country.iloc[:, 6:], pandas.Series.mean)
    df_means_per_country = convert_dict_to_df(means_per_country, "Years", "Means")


    line_per_country = create_plot(df_means_per_country["Years"],
                                   df_means_per_country["Means"],
                                   3,
                                   f"Wykres średniej rocznej produkcji prądu we wszystkich elektrowniach (OZE + konwencjonalne) dla {country} (MW)", disp_in_jupyter=False)

#################################################

# %%
#ŚREDNIA PRODUKCJA PRĄDU Z FOSSIL FUELS
df_EU_FOSSIL = df_sorted



#PRZEKONWERTUJ WARTOSCI NA LICZBY I UZUPELNIJ NA
df_EU_FOSSIL_converted = convert_to_numeric_and_fillna(df_EU_FOSSIL, 0, 6, 0)
df_EU_FOSSIL_converted

df_EU_FOSSIL.iloc[:, 6] = df_EU_FOSSIL_converted
df_EU_FOSSIL

fossil_filtered_df = df_EU_FOSSIL[((df_EU_FOSSIL["Type of fuel"] == "X9900") | (df_EU_FOSSIL["Type of fuel"] == "CF")) & (df_EU_FOSSIL["Type of measure"] == "CAP_NET_ELC") & (df_EU_FOSSIL["Operator"] == "PRR_MAIN")]
fossil_filtered_df = fossil_filtered_df[(fossil_filtered_df["Country"] != "EA20") & (fossil_filtered_df["Country"] != "EU27_2020")]
# fossil_filtered_df
fossil_filtered_df = convert_to_numeric_and_fillna(fossil_filtered_df, 0, 6, 0)


fossil_means = iter_through_cols(fossil_filtered_df.iloc[:, 6:], pandas.Series.mean)
fossil_means
fossil_means = convert_dict_to_df(fossil_means, "Years", "Means")

fossil_means

fossil_chart = create_plot(fossil_means["Years"].values, fossil_means["Means"].values, 3, "Średnia zainstalowana moc elektryczna (paliwa kopalne i inne nie OZE) ", "Średnia zainstalowana moc elektryczna (paliwa kopalne)", disp_in_jupyter=True)

# %%
#ŚREDNIA PRODUKCJA PRĄDU Z KONWENCJONALNYCH SPOSOBÓW DLA POSZCZEGÓLNYCH PAŃSTW

#WYGENERUJ TAKI SAM WYKRES JAK WYŻEJ TYLKO DLA KAŻDEGO KRAJU Z OSOBNA

list_of_all_countries = total_without_annual_column.iloc[0:, 4].unique()

list_of_conventional_fuel = ["X9900", "CF"]
# fig, ax = plt.subplots(figsize=(12, 8)) ABY ZROBIĆ PLOTY KTÓRE MAJĄ KILKA W JEDNYM. DO FUNKCJI create_plot nalezy dodac wtedy ax=ax
# ################################################## KOD JEST PRAWIDŁOWY I WYŚWIETLA MOCE NETTO PER KRAJ
for country in list_of_all_countries:
    if country == "EA20" or country == "EU27_2020":
        continue
    df_one_country = df_sorted[(df_sorted["Country"] == country)
                               & (df_sorted["Operator"] == "PRR_MAIN")
                                 & (df_sorted["Type of measure"] == "CAP_NET_ELC")
                                 & (df_sorted["Type of fuel"].isin(list_of_conventional_fuel))]

    for series_name in df_one_country.columns[6:]:
        df_one_country.loc[:, series_name] = pandas.to_numeric(df_one_country[series_name], errors='coerce').fillna(0)

    means_per_country = iter_through_cols(df_one_country.iloc[:, 6:], pandas.Series.mean)
    df_means_per_country = convert_dict_to_df(means_per_country, "Years", "Means")


    line_per_country = create_plot(df_means_per_country["Years"],
                                   df_means_per_country["Means"],
                                   3,
                                   f"Wykres średniej mocy zainstalowanej we wszystkich elektrowniach (źródła konwencjonalne) dla {country} (MW)",
                                   label_name = f"Moc zainstalowana netto dla {country} (MW)", disp_in_jupyter=False)


#################################################

# %%
# ŚREDNIA PRODUKCJA PRĄDU Z OZE
"""
    "N9000" : "Nuclear fuels and other fuels n.e.c. (energia jądrowa i inne, niesklasyfikowane)", #ECO
    "RA100" : "Hydro (energia wodna)", #ECO
    "RA110" : "Pure hydro power (czysta energia wodna)", #ECO
    "RA120" : "Mixed hydro power (mieszana energia wodna)", #ECO
    "RA130" : "Pumped hydro power (energia z elektrowni szczytowo-pompowych)", #ECO
    "RA200" : "Geothermal (energia geotermalna)", #ECO
    "RA300" : "Wind (energia wiatrowa)", #ECO
    "RA310" : "Wind on shore (wiatr na lądzie)", #ECO
    "RA320" : "Wind off shore (wiatr na morzu)", #ECO
    "RA410" : "Solar thermal (energia słoneczna - termiczna)", #ECO
    "RA420" : "Solar photovoltaic (energia słoneczna - fotowoltaika)", #ECO
    "RA420AC" : "Solar photovoltaic - alternating current (PV prądu przemiennego)", #ECO
    "RA420DC" : "Solar photovoltaic - direct current (PV prądu stałego)", #ECO
    "RA500" : "Other renewable energies (inne odnawialne źródła energii)", #ECO
"""
# extend_visibility_of_data(1000, 69)

oze_df = df_sorted[(df_sorted["Type of fuel"] != "CF") & (df_sorted["Type of fuel"] != "X9900") & (df_sorted["Type of fuel"] != "TOTAL")]
oze_df = oze_df[(oze_df["Type of measure"] == "CAP_NET_ELC") & (oze_df["Operator"] == "PRR_MAIN")]
oze_df

oze_values = convert_to_numeric_and_fillna(oze_df.iloc[:, 6:], 0, 0, 0)
# oze_df.iloc[:, 6] = oze_values

oze_means_df = iter_through_cols(oze_values, pandas.Series.mean)
oze_means_df = convert_dict_to_df(oze_means_df, "Years", "Means")
oze_means_df

oze_chart = create_plot(oze_means_df["Years"].values, oze_means_df["Means"].values, 3, "Średnia zainstalowana moc elektryczna (OZE)", "Średnia zainstalowana moc OZE (MW)", disp_in_jupyter=True)

# %%
# COMBINE WSZYSTKIE SREDNIE I ZROB TAK BY SPRAWDZIC ILE TO JEST PROCENTOWO
df_sorted_filtered_useful

conventional = df_sorted_filtered_useful[(df_sorted["Type of fuel"] == "CF") | (df_sorted["Type of fuel"] == "X9900")]
conventional = conventional.sum().to_frame().reset_index()
conventional.columns = ["Year Conventional", "Total Conventional"]

oze = df_sorted_filtered_useful[(df_sorted["Type of fuel"] != "CF") & (df_sorted["Type of fuel"] != "X9900")]
oze = oze.sum().to_frame().reset_index()
oze.columns = ["Year OZE", "Total OZE"]


total = df_sorted_filtered_useful.sum().to_frame().reset_index()
total.columns = ["Year", "Total"]


table_full = pandas.concat([total, conventional, oze], axis=1)
table_full = table_full.drop(columns=["Year Conventional", "Year OZE"])

table_full["% OZE"] = ((table_full["Total OZE"] / table_full["Total"]) * 100)
table_full["% Conventional"] = ((table_full["Total Conventional"] / table_full["Total"]) * 100)

table_full.style.format(precision=2, thousands=",")
# Out:
# /var/folders/bp/bb_7sl4n2nj06_c0wq20t5pc0000gn/T/ipykernel_3382/888049463.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   conventional = df_sorted_filtered_useful[(df_sorted["Type of fuel"] == "CF") | (df_sorted["Type of fuel"] == "X9900")]
# /var/folders/bp/bb_7sl4n2nj06_c0wq20t5pc0000gn/T/ipykernel_3382/888049463.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   oze = df_sorted_filtered_useful[(df_sorted["Type of fuel"] != "CF") & (df_sorted["Type of fuel"] != "X9900")]
# <style type="text/css">
# </style>
# <table id="T_224b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_224b8_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_224b8_level0_col1" class="col_heading level0 col1" >Total</th>
#       <th id="T_224b8_level0_col2" class="col_heading level0 col2" >Total Conventional</th>
# ...

# %%
#PROCENTOWY UDZIAŁ KONWENCJONALNYCH I OZE

fig, ax = plt.subplots(figsize=(12, 10)) #ABY ZROBIĆ PLOTY KTÓRE MAJĄ KILKA W JEDNYM. DO FUNKCJI create_plot nalezy dodac wtedy ax=ax

line1 = create_plot(table_full["Year"], table_full["Total OZE"], 3, "Porównanie mocy zainstalowanej dla OZE oraz dla elektrowni konwencjonalnych", "OZE", ax=ax)
line2 = create_plot(table_full["Year"], table_full["Total Conventional"], 3, "Porównanie mocy zainstalowanej dla OZE oraz dla elektrowni konwencjonalnych", "Konwencjonalne", ax=ax, color="red")
line2.set_color('red')

# %%
#CO NAJWIĘCEJ PODNOSI W OSTATNICH LATACH OZE
#TODO W JAKICH KRAJACH NAJWIĘKSZE WZROSTY I CZEGO 2020-2023
extend_visibility_of_data(1000, 60)


main_df = main_df.reset_index()
main_df = main_df.drop("index", axis=1)

top_OZE = main_df[~main_df["Type of fuel"].isin(["CF", "X9900"])]

#WYBIERZ KOLUMNY OPISOWE I OSTATNIE 4 LATA
top_OZE = top_OZE.iloc[:, [0,1,2,3,4,5,len(top_OZE.columns)-4, len(top_OZE.columns)-3, len(top_OZE.columns)-2, len(top_OZE.columns)-1]]

#DODAJ RÓŻNICĘ CO ROKU
for i in range(0,3):
    top_OZE.insert(len(top_OZE.columns) - (i*2), f"Difference 202{3-i}-{2022-i}", top_OZE[f"202{3-i} "] - top_OZE[f"202{2-i} "])

#TOP3 RÓŻNICA MIĘDZY LATAMI NA LATA 2023-2022
diff_2023 = top_OZE.sort_values(by='Difference 2023-2022', axis=0, ascending=0).iloc[0:3, :]

#TOP3 RÓŻNICA MIĘDZY LATAMI NA LATA 2022-2021
diff_2022 = top_OZE.sort_values(by='Difference 2022-2021', axis=0, ascending=0).iloc[0:3, :]
#TOP3 RÓŻNICA MIĘDZY LATAMI NA LATA 2021-2020
diff_2021 = top_OZE.sort_values(by='Difference 2021-2020', axis=0, ascending=0).iloc[0:3, :]

bar1 = create_bar(diff_2023["Country"] + " " + diff_2023["Type of fuel"], diff_2023["Difference 2023-2022"], x_label_name="Kraj i rodzaj elektrowni", y_label_name="Moc zainstalowana (MW)", color="skyblue", title="Największe zmiany w mocy zainstalowanej na rok 2023 (MW)")
create_labels_bar((diff_2023["Country"] + " " + diff_2023["Type of fuel"]).to_list(), diff_2023["Difference 2023-2022"].to_list(), label_color='darkblue', boxstyle='round', font_color='white')

bar2 = create_bar(diff_2022["Country"] + " " + diff_2022["Type of fuel"], diff_2022["Difference 2022-2021"], x_label_name="Kraj i rodzaj elektrowni", y_label_name="Moc zainstalowana (MW)", color="skyblue", title="Największe zmiany w mocy zainstalowanej na rok 2022 (MW)")
create_labels_bar((diff_2022["Country"] + " " + diff_2022["Type of fuel"]).to_list(), diff_2022["Difference 2022-2021"].to_list(), label_color='darkblue', boxstyle='round', font_color='white')

bar3 = create_bar(diff_2021["Country"] + " " + diff_2021["Type of fuel"], diff_2021["Difference 2021-2020"], x_label_name="Kraj i rodzaj elektrowni", y_label_name="Moc zainstalowana (MW)", color="skyblue", title="Największe zmiany w mocy zainstalowanej na rok 2021 (MW)")
create_labels_bar((diff_2021["Country"] + " " + diff_2021["Type of fuel"]).to_list(), diff_2021["Difference 2021-2020"].to_list(), label_color='darkblue', boxstyle='round', font_color='white')

# %%
#REGRESJA LINIOWA - PRZEWIDYWANIA WZROSTU PRĄDU W NASTĘPNYCH LATACH
#ŹRÓDŁA KONWENCJONALNE

fossil_fuel_sums_all = pandas.DataFrame()

for country in list_of_all_countries:
    # Sum the relevant rows for the country and transpose to row format
    sums = main_df[
        (main_df["Type of fuel"].isin(["CF", "X9900"])) &
        (main_df["Country"] == country)
    ].iloc[:, 6:].sum().to_frame().transpose()
    sums['Country'] = country  # Add the country as a column for reference
    fossil_fuel_sums_all = pandas.concat([fossil_fuel_sums_all, sums], ignore_index=True)

fossil_fuel_sums_all
plt.figure(figsize=(15, 11))
for country in list_of_all_countries:
    x_values = fossil_fuel_sums_all.columns
    x_values = x_values.drop("Country")
    x_values = x_values.astype('int64')
    x_values = x_values.values.flatten()
    y_values = fossil_fuel_sums_all[fossil_fuel_sums_all['Country'] == country].iloc[:, :-1].values.flatten()

    # print(len(x_values))
    # print(len(y_values))
    
    # test = fossil_fuel_sums_all[fossil_fuel_sums_all["Country"] == country].iloc[:, :len(fossil_fuel_sums_all.columns)-1]
    plt.scatter(x_values, y_values, label=country)
    plt.xticks(ticks=[x_values[i] for i in range(0, len(x_values), 3)],
    labels=[x_values[i] for i in range(0, len(x_values), 3)])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Wzrost mocy zainstalowanej dla elektrowni konwencjonalnych w podziale na kraje i lata")
# test
    # plt.scatter(fossil_fuel_sums_all.columns-1, fossil_fuel_sums_all[fossil_fuel_sums_all["Country"] == country].iloc[:, len(fossil_fuel_sums_all.columns)-1])
# Out:
# Text(0.5, 1.0, 'Wzrost mocy zainstalowanej dla elektrowni konwencjonalnych w podziale na kraje i lata')

# %%
#REGRESJA LINIOWA - PRZEWIDYWANIA WZROSTU PRĄDU W NASTĘPNYCH LATACH
#ŹRÓDŁA OZE
from sklearn.linear_model import LinearRegression
import numpy as np

oze_sums_all = pandas.DataFrame()

for country in list_of_all_countries:
    # Sum the relevant rows for the country and transpose to row format
    sums = main_df[
        (~main_df["Type of fuel"].isin(["CF", "X9900"])) &
        (main_df["Country"] == country)
    ].iloc[:, 6:].sum().to_frame().transpose()
    sums['Country'] = country  # Add the country as a column for reference
    oze_sums_all = pandas.concat([oze_sums_all, sums], ignore_index=True)

#MEDIANA WSZYSTKICH PAŃSTW
medians = {}
oze_sums_all.loc[:, oze_sums_all.columns != "Country"]
for col in oze_sums_all.loc[:, oze_sums_all.columns != "Country"].columns:
    medians[col] = oze_sums_all.loc[:, col].median()
median_table = pandas.DataFrame([medians])
median_table = median_table.transpose()
median_table = median_table.reset_index()
median_table = median_table.rename({"index": "Rok", 0: "Mediana"}, axis=1)


#REGRESJA
model = LinearRegression()
oze_sums_molten = oze_sums_all.melt(id_vars="Country", var_name="Year", value_name="Value")
oze_sums_molten['Year'] = pandas.to_numeric(oze_sums_molten['Year'], errors='coerce')
oze_sums_molten['Value'] = pandas.to_numeric(oze_sums_molten['Value'], errors='coerce')

model.fit(oze_sums_molten.loc[:,"Year"].to_frame(), oze_sums_molten.loc[:, "Value"].to_frame())
oze_sums_molten["regression"] = model.predict(oze_sums_molten.loc[:,"Year"].to_frame())

plt.figure(figsize=(15, 11))
for country in list_of_all_countries:
    x_values = oze_sums_all.columns
    x_values = x_values.drop("Country")
    x_values = x_values.astype('int64')
    x_values = x_values.values.flatten()
    y_values = oze_sums_all[oze_sums_all['Country'] == country].iloc[:, :-1].values
    plt.scatter(x_values, y_values, label=country)
    plt.xticks(ticks=[x_values[i] for i in range(0, len(x_values), 3)],
    labels=[x_values[i] for i in range(0, len(x_values), 3)])

line = plt.plot(oze_sums_molten.loc[:, "Year"].astype("int64"), oze_sums_molten.loc[:, "regression"], label="Regresja", color='green')
for i, (xi, yi) in enumerate(zip(oze_sums_molten.loc[:, "Year"].astype("int64").unique(), oze_sums_molten.loc[:, "regression"].unique())):
    if i % 3 == 0:
        plt.annotate(f'{yi:.1f}', xy=(xi, yi), xytext=(0,10), textcoords='offset points', fontsize=6, color='white', ha='center', bbox=dict(facecolor='green', alpha=0.8))

line2 = plt.plot(median_table.loc[:, "Rok"].astype("int64"), median_table.loc[:, "Mediana"], label="Mediana mocy zainstalowanej", color='darkred')
for i, (xi, yi) in enumerate(zip(median_table.loc[:, "Rok"].astype("int64"), median_table.loc[:, "Mediana"])):
    if i % 3 == 0:
        plt.annotate(f'{yi:.1f}', xy=(xi, yi), xytext=(0,-10), textcoords='offset points', fontsize=6, color='white', ha='center', bbox=dict(facecolor='darkred', alpha=0.8))

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Wzrost mocy zainstalowanej elektrowni OZE w podziale na kraje i lata")
plt.xlabel('Year')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
#Sprawdź jak wygląda udział OZE w czasie dla poszczególnych krajów. Wykres kropkowy jak to wygląda dla każdego kraju

# %%
#WSPÓŁCZYNNIK KORELACJI PEARSONA POMIĘDZY ŚREDNIĄ WYDAJNOŚCIĄ ENERGETYCZNĄ, A WZROSTEM ŚREDNIEGO UDZIAŁU OZE

# %%
#NORMALIZACJA

# %%
#PRZEDSTAWIENIE WYDAJNOSCI ENERGETYCZNEJ KAZDEGO Z PANSTW W POROWNANIU DO WZROSTU OZE JAKO OGOLU PER PANSTWO
